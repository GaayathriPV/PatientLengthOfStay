# %% [markdown]
# # Predictive Analytics on Patient Length of Stay

# %% [markdown]
# **Team Members**
# Kolla Sahithi - Data preprocessing and Data Handling along with visualizations revolving it
# Gaayathri Vaidhyanathan Pazhambalacode - Data Analysis, Answering visualization questions, and modeling

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## 1. Available features and their descriptions
# Case_Id : Storing Unique ids with respect to cases
# Hospital_Code : Unique Code for Hospitals in which particular case is being investigated
# Hospital_type_code : Unique Code for Type of Hospitals
# Hospital_region_code : Region of Hospitals
# Available Extra Rooms in Hospital : No. of extra rooms available
# Department : Department overlooking the case
# Ward_Type : Unique code for ward type
# Ward_Facility_Code : Unique code for ward facility
# Bed Grade : Condition for Bed in Hospital
# Patient_Id : Patient id undergoing current case
# City_Code_Patient : City code for the patient
# Type_of_Admission : Admission type registered by hospital
# Severity of illness : severity recorded at time of admission
# Visitors with Patient : No. of visitors with patient
# Age : Age of the patient
# Admission_Deposit : Deposit at admission time
# Stay : Target Variable Stay which depicts no. of days the patient stayed at hospital

# %% [markdown]
# ## 2. Reading the training and testing datasets

# %%
#Reading data

raw_train_data = pd.read_csv('original.csv')

# %% [markdown]
# ## 3. Data Understanding
#
# > 3.1 Display the raw dataset
#
# > 3.2 Understanding descriptive features
#
# > 3.3 Understand the data types

# %% [markdown]
# ### 3.1 Display Raw Dataset

# %%
raw_train_data
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0             1              8                  c                   3
# 1             2              2                  c                   5
# 2             3             10                  e                   1
# 3             4             26                  b                   2
# 4             5             26                  b                   2
# ...         ...            ...                ...                 ...
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                         Z                                  3  radiotherapy
# 1                         Z                                  2  radiotherapy
# 2                         X                                  2    anesthesia
# 3                         Y                                  2  radiotherapy
# 4                         Y                                  2  radiotherapy
# ...                     ...                                ...           ...
# 318433                    X                                  3  radiotherapy
# 318434                    X                                  2    anesthesia
# 318435                    X                                  3    gynecology
# 318436                    Y                                  3    anesthesia
# 318437                    Y                                  5    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0              R                  F        2.0      31397                7.0
# 1              S                  F        2.0      31397                7.0
# 2              S                  E        2.0      31397                7.0
# 3              R                  D        2.0      31397                7.0
# 4              S                  D        2.0      31397                7.0
# ...          ...                ...        ...        ...                ...
# 318433         Q                  F        4.0      86499               23.0
# 318434         Q                  E        4.0        325                8.0
# 318435         R                  F        4.0     125235               10.0
# 318436         Q                  D        3.0      91081                8.0
# 318437         Q                  C        2.0      21641                8.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0              Emergency             Extreme                      2  51-60
# 1                 Trauma             Extreme                      2  51-60
# 2                 Trauma             Extreme                      2  51-60
# 3                 Trauma             Extreme                      2  51-60
# 4                 Trauma             Extreme                      2  51-60
# ...                  ...                 ...                    ...    ...
# 318433         Emergency            Moderate                      3  41-50
# 318434            Urgent            Moderate                      4  81-90
# 318435         Emergency               Minor                      3  71-80
# 318436            Trauma               Minor                      5  11-20
# 318437         Emergency               Minor                      2  11-20
#
#         Admission_Deposit   Stay
# 0                  4911.0   0-10
# 1                  5954.0  41-50
# 2                  4745.0  31-40
# 3                  7272.0  41-50
# 4                  5558.0  41-50
# ...                   ...    ...
# 318433             4144.0  11-20
# 318434             6699.0  31-40
# 318435             4235.0  11-20
# 318436             3761.0  11-20
# 318437             4752.0   0-10
#
# [318438 rows x 18 columns]

# %% [markdown]
# #### By observing data we can see that we don't need case_id and hospital_code

# %% [markdown]
# ### 3.2 Understanding Descriptive Featuers

# %%
raw_train_data.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit', 'Stay'],
#       dtype='object')

# %%
raw_train_data.shape
# Out:
# (318438, 18)

# %%
raw_train_data['Admission_Deposit']
# Out:
# 0         4911.0
# 1         5954.0
# 2         4745.0
# 3         7272.0
# 4         5558.0
#            ...
# 318433    4144.0
# 318434    6699.0
# 318435    4235.0
# 318436    3761.0
# 318437    4752.0
# Name: Admission_Deposit, Length: 318438, dtype: float64

# %% [markdown]
# ### 3.3 Understand the data types

# %%
raw_train_data.dtypes
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# Stay                                  object
# dtype: object

# %% [markdown]
# ## 4. Data Exploration
#
# > 4.1 Prepare Data Quality Report
#
# >> 4.1.1 Data Quality Report for Categorical Descriptive Features
#
# >> 4.1.2 Data Quality Report for Continuous Descritive Features
#
# > 4.2 Data Visualization
#
# > 4.3 Determine the Data Quality Issues - Missing Values and Outliers
#
# > 4.4 Handling Data Quality Issues

# %% [markdown]
# ### 4.1 Prepare Data Quality Report

# %%
cat_features = raw_train_data.select_dtypes(include='object')

# %%
cat_features = list(cat_features.columns)

# %%
# we have some features whose values are numeric but need to be considered as categorical. we will append them.

# %%
cat_features.append('Hospital_code')
cat_features.append('City_Code_Hospital')

# %%
cat_features.append('Bed Grade')
cat_features.append('City_Code_Patient')

# %%
cat_features.append('Available Extra Rooms in Hospital')
cat_features.append('Visitors with Patient')

# %%
cat_features
# Out:
# ['Hospital_type_code',
#  'Hospital_region_code',
#  'Department',
#  'Ward_Type',
#  'Ward_Facility_Code',
#  'Type of Admission',
#  'Severity of Illness',
#  'Age',
#  'Stay',
#  'Hospital_code',
#  'City_Code_Hospital',
#  'Bed Grade',
#  'City_Code_Patient',
#  'Available Extra Rooms in Hospital',
#  'Visitors with Patient']

# %%
#cat_features.remove('Bed Grade')

# %%
cat_features.remove('City_Code_Hospital')

# %%
# following are available categorical features

# %%
cat_features
# Out:
# ['Hospital_type_code',
#  'Hospital_region_code',
#  'Department',
#  'Ward_Type',
#  'Ward_Facility_Code',
#  'Type of Admission',
#  'Severity of Illness',
#  'Age',
#  'Stay',
#  'Hospital_code',
#  'Bed Grade',
#  'City_Code_Patient',
#  'Available Extra Rooms in Hospital',
#  'Visitors with Patient']

# %%
print('There are total {} categorical features in the data'.format(len(cat_features)))
# Out:
# There are total 14 categorical features in the data

# %%
set(list(raw_train_data.columns)) - set(cat_features)
# Out:
# {'Admission_Deposit', 'City_Code_Hospital', 'case_id', 'patientid'}

# %%
# describe function will work on categorical features whose values are numerical. So we will get only few features
# from cat_features array here. For others we need to work manually.
raw_train_data[cat_features].describe().transpose()
# Out:
#                                       count       mean       std  min   25%  \
# Hospital_code                      318438.0  18.318841  8.633755  1.0  11.0
# Bed Grade                          318325.0   2.625807  0.873146  1.0   2.0
# City_Code_Patient                  313906.0   7.251859  4.745266  1.0   4.0
# Available Extra Rooms in Hospital  318438.0   3.197627  1.168171  0.0   2.0
# Visitors with Patient              318438.0   3.284099  1.764061  0.0   2.0
#
#                                     50%   75%   max
# Hospital_code                      19.0  26.0  32.0
# Bed Grade                           3.0   3.0   4.0
# City_Code_Patient                   8.0   8.0  38.0
# Available Extra Rooms in Hospital   3.0   4.0  24.0
# Visitors with Patient               3.0   4.0  32.0

# %%
# we need to calculate following:
# % missing, Mode, Second Mode, Mode freqn, second mode freqn, Mode %, 2nd Mode %, Cardinality,

# %%
raw_train_data['City_Code_Hospital'].unique().sort()

# %%
len(cat_features)
# Out:
# 14

# %%
raw_train_data[cat_features].dtypes
# Out:
# Hospital_type_code                    object
# Hospital_region_code                  object
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Type of Admission                     object
# Severity of Illness                   object
# Age                                   object
# Stay                                  object
# Hospital_code                          int64
# Bed Grade                            float64
# City_Code_Patient                    float64
# Available Extra Rooms in Hospital      int64
# Visitors with Patient                  int64
# dtype: object

# %%
cat_data_desc = raw_train_data[cat_features].describe(include=['object', 'int64', 'float64']).transpose()
cat_data_desc
# Out:
#                                       count unique         top    freq  \
# Hospital_type_code                   318438      7           a  143425
# Hospital_region_code                 318438      3           X  133336
# Department                           318438      5  gynecology  249486
# Ward_Type                            318438      6           R  127947
# Ward_Facility_Code                   318438      6           F  112753
# Type of Admission                    318438      3      Trauma  152261
# Severity of Illness                  318438      3    Moderate  175843
# Age                                  318438     10       41-50   63749
# Stay                                 318438     11       21-30   87491
# Hospital_code                      318438.0    NaN         NaN     NaN
# Bed Grade                          318325.0    NaN         NaN     NaN
# City_Code_Patient                  313906.0    NaN         NaN     NaN
# Available Extra Rooms in Hospital  318438.0    NaN         NaN     NaN
# Visitors with Patient              318438.0    NaN         NaN     NaN
#
#                                         mean       std  min   25%   50%   75%  \
# Hospital_type_code                       NaN       NaN  NaN   NaN   NaN   NaN
# Hospital_region_code                     NaN       NaN  NaN   NaN   NaN   NaN
# Department                               NaN       NaN  NaN   NaN   NaN   NaN
# Ward_Type                                NaN       NaN  NaN   NaN   NaN   NaN
# Ward_Facility_Code                       NaN       NaN  NaN   NaN   NaN   NaN
# Type of Admission                        NaN       NaN  NaN   NaN   NaN   NaN
# Severity of Illness                      NaN       NaN  NaN   NaN   NaN   NaN
# Age                                      NaN       NaN  NaN   NaN   NaN   NaN
# Stay                                     NaN       NaN  NaN   NaN   NaN   NaN
# Hospital_code                      18.318841  8.633755  1.0  11.0  19.0  26.0
# Bed Grade                           2.625807  0.873146  1.0   2.0   3.0   3.0
# City_Code_Patient                   7.251859  4.745266  1.0   4.0   8.0   8.0
# Available Extra Rooms in Hospital   3.197627  1.168171  0.0   2.0   3.0   4.0
# Visitors with Patient               3.284099  1.764061  0.0   2.0   3.0   4.0
#
#                                     max
# Hospital_type_code                  NaN
# Hospital_region_code                NaN
# Department                          NaN
# Ward_Type                           NaN
# Ward_Facility_Code                  NaN
# Type of Admission                   NaN
# Severity of Illness                 NaN
# Age                                 NaN
# Stay                                NaN
# Hospital_code                      32.0
# Bed Grade                           4.0
# City_Code_Patient                  38.0
# Available Extra Rooms in Hospital  24.0
# Visitors with Patient              32.0

# %%
cat_data_desc.drop(['mean','std','min','25%','50%', '75%','max'], inplace=True, axis=1)

# %%
cat_data_desc
# Out:
#                                       count unique         top    freq
# Hospital_type_code                   318438      7           a  143425
# Hospital_region_code                 318438      3           X  133336
# Department                           318438      5  gynecology  249486
# Ward_Type                            318438      6           R  127947
# Ward_Facility_Code                   318438      6           F  112753
# Type of Admission                    318438      3      Trauma  152261
# Severity of Illness                  318438      3    Moderate  175843
# Age                                  318438     10       41-50   63749
# Stay                                 318438     11       21-30   87491
# Hospital_code                      318438.0    NaN         NaN     NaN
# Bed Grade                          318325.0    NaN         NaN     NaN
# City_Code_Patient                  313906.0    NaN         NaN     NaN
# Available Extra Rooms in Hospital  318438.0    NaN         NaN     NaN
# Visitors with Patient              318438.0    NaN         NaN     NaN

# %%
added_missing_data = pd.DataFrame(raw_train_data[cat_features].isna().sum(), columns=['Missing Values'])

# %%
added_missing_data.reset_index(level=0, inplace=True)
added_missing_data
# Out:
#                                 index  Missing Values
# 0                  Hospital_type_code               0
# 1                Hospital_region_code               0
# 2                          Department               0
# 3                           Ward_Type               0
# 4                  Ward_Facility_Code               0
# 5                   Type of Admission               0
# 6                 Severity of Illness               0
# 7                                 Age               0
# 8                                Stay               0
# 9                       Hospital_code               0
# 10                          Bed Grade             113
# 11                  City_Code_Patient            4532
# 12  Available Extra Rooms in Hospital               0
# 13              Visitors with Patient               0

# %%
added_missing_data.rename(columns = {'index': 'Features'}, inplace=True)

# %%
added_missing_data
# Out:
#                              Features  Missing Values
# 0                  Hospital_type_code               0
# 1                Hospital_region_code               0
# 2                          Department               0
# 3                           Ward_Type               0
# 4                  Ward_Facility_Code               0
# 5                   Type of Admission               0
# 6                 Severity of Illness               0
# 7                                 Age               0
# 8                                Stay               0
# 9                       Hospital_code               0
# 10                          Bed Grade             113
# 11                  City_Code_Patient            4532
# 12  Available Extra Rooms in Hospital               0
# 13              Visitors with Patient               0

# %%
cat_data_desc.reset_index(level=0, inplace=True)

# %%
cat_data_desc
# Out:
#                                 index     count unique         top    freq
# 0                  Hospital_type_code    318438      7           a  143425
# 1                Hospital_region_code    318438      3           X  133336
# 2                          Department    318438      5  gynecology  249486
# 3                           Ward_Type    318438      6           R  127947
# 4                  Ward_Facility_Code    318438      6           F  112753
# 5                   Type of Admission    318438      3      Trauma  152261
# 6                 Severity of Illness    318438      3    Moderate  175843
# 7                                 Age    318438     10       41-50   63749
# 8                                Stay    318438     11       21-30   87491
# 9                       Hospital_code  318438.0    NaN         NaN     NaN
# 10                          Bed Grade  318325.0    NaN         NaN     NaN
# 11                  City_Code_Patient  313906.0    NaN         NaN     NaN
# 12  Available Extra Rooms in Hospital  318438.0    NaN         NaN     NaN
# 13              Visitors with Patient  318438.0    NaN         NaN     NaN

# %%
cat_data_desc.rename(columns = {'index': 'Features'}, inplace=True)

# %%
cat_data_desc.drop(['unique','top','freq'], inplace=True, axis=1)

# %%
unique_vals = pd.DataFrame(raw_train_data.nunique(), columns=['unique'])

# %%
unique_vals.reset_index(level=0, inplace=True)
unique_vals.rename(columns = {'index': 'Features'}, inplace=True)

# %%
unique_vals
# Out:
#                              Features  unique
# 0                             case_id  318438
# 1                       Hospital_code      32
# 2                  Hospital_type_code       7
# 3                  City_Code_Hospital      11
# 4                Hospital_region_code       3
# 5   Available Extra Rooms in Hospital      18
# 6                          Department       5
# 7                           Ward_Type       6
# 8                  Ward_Facility_Code       6
# 9                           Bed Grade       4
# 10                          patientid   92017
# 11                  City_Code_Patient      37
# 12                  Type of Admission       3
# 13                Severity of Illness       3
# 14              Visitors with Patient      28
# 15                                Age      10
# 16                  Admission_Deposit    7300
# 17                               Stay      11

# %%
cat_data_summary = pd.merge(unique_vals, cat_data_desc, on='Features')

# %%
cat_data_summary
# Out:
#                              Features  unique     count
# 0                       Hospital_code      32  318438.0
# 1                  Hospital_type_code       7    318438
# 2                Hospital_region_code       3    318438
# 3   Available Extra Rooms in Hospital      18  318438.0
# 4                          Department       5    318438
# 5                           Ward_Type       6    318438
# 6                  Ward_Facility_Code       6    318438
# 7                           Bed Grade       4  318325.0
# 8                   City_Code_Patient      37  313906.0
# 9                   Type of Admission       3    318438
# 10                Severity of Illness       3    318438
# 11              Visitors with Patient      28  318438.0
# 12                                Age      10    318438
# 13                               Stay      11    318438

# %%
added_missing_data
# Out:
#                              Features  Missing Values
# 0                  Hospital_type_code               0
# 1                Hospital_region_code               0
# 2                          Department               0
# 3                           Ward_Type               0
# 4                  Ward_Facility_Code               0
# 5                   Type of Admission               0
# 6                 Severity of Illness               0
# 7                                 Age               0
# 8                                Stay               0
# 9                       Hospital_code               0
# 10                          Bed Grade             113
# 11                  City_Code_Patient            4532
# 12  Available Extra Rooms in Hospital               0
# 13              Visitors with Patient               0

# %%
cat_data_summary = pd.merge(cat_data_summary, added_missing_data, on='Features')

# %%
cat_data_summary['% of missing'] = cat_data_summary['Missing Values']/cat_data_summary['count']

# %%
cat_data_summary['% of missing'] = cat_data_summary['% of missing']*100

# %%
cat_data_summary.drop(['Missing Values'], inplace=True, axis = 1)

# %%
cat_data_summary
# Out:
#                              Features  unique     count % of missing
# 0                       Hospital_code      32  318438.0          0.0
# 1                  Hospital_type_code       7    318438          0.0
# 2                Hospital_region_code       3    318438          0.0
# 3   Available Extra Rooms in Hospital      18  318438.0          0.0
# 4                          Department       5    318438          0.0
# 5                           Ward_Type       6    318438          0.0
# 6                  Ward_Facility_Code       6    318438          0.0
# 7                           Bed Grade       4  318325.0     0.035498
# 8                   City_Code_Patient      37  313906.0     1.443744
# 9                   Type of Admission       3    318438          0.0
# 10                Severity of Illness       3    318438          0.0
# 11              Visitors with Patient      28  318438.0          0.0
# 12                                Age      10    318438          0.0
# 13                               Stay      11    318438          0.0

# %%
mode_data = raw_train_data[cat_features].mode().transpose()

# %%
mode_data.reset_index(level=0, inplace=True)

# %%
mode_data
# Out:
#                                 index           0
# 0                  Hospital_type_code           a
# 1                Hospital_region_code           X
# 2                          Department  gynecology
# 3                           Ward_Type           R
# 4                  Ward_Facility_Code           F
# 5                   Type of Admission      Trauma
# 6                 Severity of Illness    Moderate
# 7                                 Age       41-50
# 8                                Stay       21-30
# 9                       Hospital_code          26
# 10                          Bed Grade         2.0
# 11                  City_Code_Patient         8.0
# 12  Available Extra Rooms in Hospital           2
# 13              Visitors with Patient           2

# %%
mode_data.rename(columns = {'index': 'Features', 0:'Mode'}, inplace=True)

# %%
mode_data
# Out:
#                              Features        Mode
# 0                  Hospital_type_code           a
# 1                Hospital_region_code           X
# 2                          Department  gynecology
# 3                           Ward_Type           R
# 4                  Ward_Facility_Code           F
# 5                   Type of Admission      Trauma
# 6                 Severity of Illness    Moderate
# 7                                 Age       41-50
# 8                                Stay       21-30
# 9                       Hospital_code          26
# 10                          Bed Grade         2.0
# 11                  City_Code_Patient         8.0
# 12  Available Extra Rooms in Hospital           2
# 13              Visitors with Patient           2

# %%
cat_data_summary = pd.merge(cat_data_summary, mode_data, on='Features')

# %%
cat_data_summary
# Out:
#                              Features  unique     count % of missing  \
# 0                       Hospital_code      32  318438.0          0.0
# 1                  Hospital_type_code       7    318438          0.0
# 2                Hospital_region_code       3    318438          0.0
# 3   Available Extra Rooms in Hospital      18  318438.0          0.0
# 4                          Department       5    318438          0.0
# 5                           Ward_Type       6    318438          0.0
# 6                  Ward_Facility_Code       6    318438          0.0
# 7                           Bed Grade       4  318325.0     0.035498
# 8                   City_Code_Patient      37  313906.0     1.443744
# 9                   Type of Admission       3    318438          0.0
# 10                Severity of Illness       3    318438          0.0
# 11              Visitors with Patient      28  318438.0          0.0
# 12                                Age      10    318438          0.0
# 13                               Stay      11    318438          0.0
#
#           Mode
# 0           26
# 1            a
# 2            X
# 3            2
# 4   gynecology
# 5            R
# 6            F
# 7          2.0
# 8          8.0
# 9       Trauma
# 10    Moderate
# 11           2
# 12       41-50
# 13       21-30

# %%
raw_train_data['Ward_Facility_Code'].value_counts()[1]
# Out:
# 55351

# %%
keys = []
values = []
for col in cat_data_summary['Features']:
    lol = dict(raw_train_data[col].value_counts())
    key, value = list(lol.items())[1]
    keys.append(key)
    values.append(value)

# %%
keys
# Out:
# [23,
#  'b',
#  'Y',
#  4,
#  'anesthesia',
#  'Q',
#  'E',
#  3.0,
#  2.0,
#  'Emergency',
#  'Minor',
#  4,
#  '31-40',
#  '11-20']

# %%
values
# Out:
# [26566,
#  68946,
#  122428,
#  91709,
#  29649,
#  106165,
#  55351,
#  110583,
#  38869,
#  117676,
#  85872,
#  79225,
#  63639,
#  78139]

# %%
valueCountsCat = pd.DataFrame(index = keys, columns = ["Score"], data = values)

# %%
valueCountsCat
# Out:
#              Score
# 23           26566
# b            68946
# Y           122428
# 4            91709
# anesthesia   29649
# Q           106165
# E            55351
# 3.0         110583
# 2.0          38869
# Emergency   117676
# Minor        85872
# 4            79225
# 31-40        63639
# 11-20        78139

# %%
valueCountsCat.reset_index(level=0, inplace=True)
#valueCountsCat.drop('level_0',axis=1, inplace=True)
valueCountsCat.rename({'index': '2nd Mode', 'Score': '2nd Mode Freqn'}, axis =1, inplace=True)
valueCountsCat
# Out:
#       2nd Mode  2nd Mode Freqn
# 0           23           26566
# 1            b           68946
# 2            Y          122428
# 3            4           91709
# 4   anesthesia           29649
# 5            Q          106165
# 6            E           55351
# 7          3.0          110583
# 8          2.0           38869
# 9    Emergency          117676
# 10       Minor           85872
# 11           4           79225
# 12       31-40           63639
# 13       11-20           78139

# %%
valueCountsCat.reset_index(level=0, inplace=True)
cat_data_summary.reset_index(level=0, inplace=True)

# %%
valueCountsCat
# Out:
#     index    2nd Mode  2nd Mode Freqn
# 0       0          23           26566
# 1       1           b           68946
# 2       2           Y          122428
# 3       3           4           91709
# 4       4  anesthesia           29649
# 5       5           Q          106165
# 6       6           E           55351
# 7       7         3.0          110583
# 8       8         2.0           38869
# 9       9   Emergency          117676
# 10     10       Minor           85872
# 11     11           4           79225
# 12     12       31-40           63639
# 13     13       11-20           78139

# %%
cat_data_summary = pd.merge(cat_data_summary, valueCountsCat, on='index')
cat_data_summary.drop(['index'], inplace=True, axis=1)

# %%
cat_data_summary
# Out:
#                              Features  unique     count % of missing  \
# 0                       Hospital_code      32  318438.0          0.0
# 1                  Hospital_type_code       7    318438          0.0
# 2                Hospital_region_code       3    318438          0.0
# 3   Available Extra Rooms in Hospital      18  318438.0          0.0
# 4                          Department       5    318438          0.0
# 5                           Ward_Type       6    318438          0.0
# 6                  Ward_Facility_Code       6    318438          0.0
# 7                           Bed Grade       4  318325.0     0.035498
# 8                   City_Code_Patient      37  313906.0     1.443744
# 9                   Type of Admission       3    318438          0.0
# 10                Severity of Illness       3    318438          0.0
# 11              Visitors with Patient      28  318438.0          0.0
# 12                                Age      10    318438          0.0
# 13                               Stay      11    318438          0.0
#
#           Mode    2nd Mode  2nd Mode Freqn
# 0           26          23           26566
# 1            a           b           68946
# 2            X           Y          122428
# 3            2           4           91709
# 4   gynecology  anesthesia           29649
# 5            R           Q          106165
# 6            F           E           55351
# 7          2.0         3.0          110583
# 8          8.0         2.0           38869
# 9       Trauma   Emergency          117676
# 10    Moderate       Minor           85872
# 11           2           4           79225
# 12       41-50       31-40           63639
# 13       21-30       11-20           78139

# %%
keys = []
values = []
for col in cat_data_summary['Features']:
    lol = dict(raw_train_data[col].value_counts())
    key, value = list(lol.items())[0]
    keys.append(key)
    values.append(value)

# %%
values
# Out:
# [33076,
#  143425,
#  133336,
#  98311,
#  249486,
#  127947,
#  112753,
#  123671,
#  124011,
#  152261,
#  175843,
#  138417,
#  63749,
#  87491]

# %%
keys
# Out:
# [26,
#  'a',
#  'X',
#  2,
#  'gynecology',
#  'R',
#  'F',
#  2.0,
#  8.0,
#  'Trauma',
#  'Moderate',
#  2,
#  '41-50',
#  '21-30']

# %%
valueCountsCat1 = pd.DataFrame(index = keys, columns = ["Score"], data = values)

# %%
valueCountsCat1.reset_index(level=0, inplace=True)
#valueCountsCat.drop('level_0',axis=1, inplace=True)
valueCountsCat1.rename({'index': 'Mode', 'Score': 'Mode Freqn'}, axis =1, inplace=True)
valueCountsCat1
# Out:
#           Mode  Mode Freqn
# 0           26       33076
# 1            a      143425
# 2            X      133336
# 3            2       98311
# 4   gynecology      249486
# 5            R      127947
# 6            F      112753
# 7          2.0      123671
# 8          8.0      124011
# 9       Trauma      152261
# 10    Moderate      175843
# 11           2      138417
# 12       41-50       63749
# 13       21-30       87491

# %%
valueCountsCat1.reset_index(level=0, inplace=True)
cat_data_summary.reset_index(level=0, inplace=True)

# %%
cat_data_summaryx = pd.merge(cat_data_summary, valueCountsCat1, on='index')
cat_data_summaryx.drop(['index'], inplace=True, axis=1)

# %%
cat_data_summaryx.drop(['Mode_x'], inplace=True, axis=1)

# %%
cat_data_summaryx.rename({'Mode_y': 'Mode'}, inplace=True, axis=1)

# %%
cat_data_summary= cat_data_summaryx

# %%
cat_data_summary['Mode %'] = cat_data_summary['Mode Freqn']/cat_data_summary['count']
cat_data_summary['2nd Mode %'] = cat_data_summary['2nd Mode Freqn']/cat_data_summary['count']

# %%
cat_data_summary.rename({'unique': 'Card.'}, inplace=True, axis=1)

# %%
cat_data_summary
# Out:
#                              Features  Card.     count % of missing  \
# 0                       Hospital_code     32  318438.0          0.0
# 1                  Hospital_type_code      7    318438          0.0
# 2                Hospital_region_code      3    318438          0.0
# 3   Available Extra Rooms in Hospital     18  318438.0          0.0
# 4                          Department      5    318438          0.0
# 5                           Ward_Type      6    318438          0.0
# 6                  Ward_Facility_Code      6    318438          0.0
# 7                           Bed Grade      4  318325.0     0.035498
# 8                   City_Code_Patient     37  313906.0     1.443744
# 9                   Type of Admission      3    318438          0.0
# 10                Severity of Illness      3    318438          0.0
# 11              Visitors with Patient     28  318438.0          0.0
# 12                                Age     10    318438          0.0
# 13                               Stay     11    318438          0.0
#
#       2nd Mode  2nd Mode Freqn        Mode  Mode Freqn    Mode % 2nd Mode %
# 0           23           26566          26       33076   0.10387   0.083426
# 1            b           68946           a      143425  0.450402   0.216513
# 2            Y          122428           X      133336  0.418719   0.384464
# 3            4           91709           2       98311  0.308729   0.287996
# 4   anesthesia           29649  gynecology      249486  0.783468   0.093108
# 5            Q          106165           R      127947  0.401796   0.333393
# 6            E           55351           F      112753  0.354081    0.17382
# 7          3.0          110583         2.0      123671  0.388505    0.34739
# 8          2.0           38869         8.0      124011  0.395058   0.123824
# 9    Emergency          117676      Trauma      152261   0.47815   0.369541
# 10       Minor           85872    Moderate      175843  0.552205   0.269666
# 11           4           79225           2      138417  0.434675   0.248793
# 12       31-40           63639       41-50       63749  0.200193   0.199847
# 13       11-20           78139       21-30       87491  0.274751   0.245382

# %%
set(raw_train_data.columns) - set(cat_features)
# Out:
# {'Admission_Deposit', 'City_Code_Hospital', 'case_id', 'patientid'}

# %%
cat_data_summary.loc[len(cat_data_summary.index)] = ['City_Code_Hospital', 11, 318438, 0, 2, 51809,1,55351,55351/318438, 51809/318438]

# %%
raw_train_data['City_Code_Hospital'].value_counts()
# Out:
# 1     55351
# 2     51809
# 6     46991
# 7     35463
# 3     31569
# 5     31105
# 9     26277
# 11    17137
# 4     13857
# 10     5249
# 13     3630
# Name: City_Code_Hospital, dtype: int64

# %%
cat_data_summary
# Out:
#                              Features  Card.     count % of missing  \
# 0                       Hospital_code     32  318438.0          0.0
# 1                  Hospital_type_code      7    318438          0.0
# 2                Hospital_region_code      3    318438          0.0
# 3   Available Extra Rooms in Hospital     18  318438.0          0.0
# 4                          Department      5    318438          0.0
# 5                           Ward_Type      6    318438          0.0
# 6                  Ward_Facility_Code      6    318438          0.0
# 7                           Bed Grade      4  318325.0     0.035498
# 8                   City_Code_Patient     37  313906.0     1.443744
# 9                   Type of Admission      3    318438          0.0
# 10                Severity of Illness      3    318438          0.0
# 11              Visitors with Patient     28  318438.0          0.0
# 12                                Age     10    318438          0.0
# 13                               Stay     11    318438          0.0
# 14                 City_Code_Hospital     11    318438            0
#
#       2nd Mode  2nd Mode Freqn        Mode  Mode Freqn    Mode % 2nd Mode %
# 0           23           26566          26       33076   0.10387   0.083426
# 1            b           68946           a      143425  0.450402   0.216513
# 2            Y          122428           X      133336  0.418719   0.384464
# 3            4           91709           2       98311  0.308729   0.287996
# 4   anesthesia           29649  gynecology      249486  0.783468   0.093108
# 5            Q          106165           R      127947  0.401796   0.333393
# 6            E           55351           F      112753  0.354081    0.17382
# 7          3.0          110583         2.0      123671  0.388505    0.34739
# 8          2.0           38869         8.0      124011  0.395058   0.123824
# 9    Emergency          117676      Trauma      152261   0.47815   0.369541
# 10       Minor           85872    Moderate      175843  0.552205   0.269666
# 11           4           79225           2      138417  0.434675   0.248793
# 12       31-40           63639       41-50       63749  0.200193   0.199847
# 13       11-20           78139       21-30       87491  0.274751   0.245382
# 14           2           51809           1       55351   0.17382   0.162697

# %%
raw_train_data['Department'].value_counts()
# Out:
# gynecology            249486
# anesthesia             29649
# radiotherapy           28516
# TB & Chest disease      9586
# surgery                 1201
# Name: Department, dtype: int64

# %%
cat_data_summary['Mode %'] = cat_data_summary['Mode %']*100
cat_data_summary['2nd Mode %'] = cat_data_summary['2nd Mode %']*100

# %% [markdown]
# ### 4.1.1 Data Quality Report for Categorical Descriptive Features

# %%
cat_data_summary
# Out:
#                              Features  Card.     count % of missing  \
# 0                       Hospital_code     32  318438.0          0.0
# 1                  Hospital_type_code      7    318438          0.0
# 2                Hospital_region_code      3    318438          0.0
# 3   Available Extra Rooms in Hospital     18  318438.0          0.0
# 4                          Department      5    318438          0.0
# 5                           Ward_Type      6    318438          0.0
# 6                  Ward_Facility_Code      6    318438          0.0
# 7                           Bed Grade      4  318325.0     0.035498
# 8                   City_Code_Patient     37  313906.0     1.443744
# 9                   Type of Admission      3    318438          0.0
# 10                Severity of Illness      3    318438          0.0
# 11              Visitors with Patient     28  318438.0          0.0
# 12                                Age     10    318438          0.0
# 13                               Stay     11    318438          0.0
# 14                 City_Code_Hospital     11    318438            0
#
#       2nd Mode  2nd Mode Freqn        Mode  Mode Freqn     Mode % 2nd Mode %
# 0           23           26566          26       33076  10.386951   8.342597
# 1            b           68946           a      143425  45.040165   21.65131
# 2            Y          122428           X      133336  41.871887  38.446417
# 3            4           91709           2       98311  30.872886  28.799641
# 4   anesthesia           29649  gynecology      249486  78.346805   9.310761
# 5            Q          106165           R      127947  40.179564    33.3393
# 6            E           55351           F      112753  35.408149  17.382034
# 7          3.0          110583         2.0      123671  38.850546  34.739025
# 8          2.0           38869         8.0      124011  39.505776  12.382369
# 9    Emergency          117676      Trauma      152261  47.814959  36.954132
# 10       Minor           85872    Moderate      175843  55.220482  26.966631
# 11           4           79225           2      138417  43.467488  24.879254
# 12       31-40           63639       41-50       63749  20.019282  19.984738
# 13       11-20           78139       21-30       87491   27.47505  24.538215
# 14           2           51809           1       55351  17.382034  16.269729

# %%
set(raw_train_data.columns) - set(cat_data_summary['Features'])
# Out:
# {'Admission_Deposit', 'case_id', 'patientid'}

# %%
x = pd.DataFrame(raw_train_data['Admission_Deposit'].describe().transpose())

# %%
x = x.transpose()

# %%
x
# Out:
#                       count         mean          std     min     25%     50%  \
# Admission_Deposit  318438.0  4880.749392  1086.776254  1800.0  4186.0  4741.0
#
#                       75%      max
# Admission_Deposit  5409.0  11008.0

# %%
raw_train_data['Admission_Deposit'].isna().sum()
# Out:
# 0

# %%
raw_train_data['Admission_Deposit'].nunique()
# Out:
# 7300

# %%
x["% of missing"] = 0
x['Card.'] = 7300
x['Median'] = raw_train_data['Admission_Deposit'].median()

# %%
x
# Out:
#                       count         mean          std     min     25%     50%  \
# Admission_Deposit  318438.0  4880.749392  1086.776254  1800.0  4186.0  4741.0
#
#                       75%      max  % of missing  Card.  Median
# Admission_Deposit  5409.0  11008.0             0   7300  4741.0

# %%
x.rename({'25%':'Q1', 'Q2':'Q3'}, axis=1, inplace=True)

# %%
x
# Out:
#                       count         mean          std     min      Q1     50%  \
# Admission_Deposit  318438.0  4880.749392  1086.776254  1800.0  4186.0  4741.0
#
#                       75%      max  % of missing  Card.  Median
# Admission_Deposit  5409.0  11008.0             0   7300  4741.0

# %%
x.drop(['50%'], inplace=True, axis=1)

# %%
x.reset_index(level=0, inplace=True)

# %%
x
# Out:
#                index     count         mean          std     min      Q1  \
# 0  Admission_Deposit  318438.0  4880.749392  1086.776254  1800.0  4186.0
#
#       75%      max  % of missing  Card.  Median
# 0  5409.0  11008.0             0   7300  4741.0

# %%
x.rename({'index':'Features'}, inplace=True, axis=1)

# %% [markdown]
# ### 4.1.2 Data Quality Report for Continuous Descriptive Features

# %%
x
# Out:
#             Features     count         mean          std     min      Q1  \
# 0  Admission_Deposit  318438.0  4880.749392  1086.776254  1800.0  4186.0
#
#       75%      max  % of missing  Card.  Median
# 0  5409.0  11008.0             0   7300  4741.0

# %% [markdown]
# ### 4.2 Data Visualization

# %%
sns.displot(x = np.log(raw_train_data.Admission_Deposit), kind='hist').set(title='Histogram of Admission_deposit')

# %%
sns.displot(x = np.log(raw_train_data.Admission_Deposit), kind='kde').set(title='Density Function of Admission_deposit')

# %%
plt.hist(raw_train_data.Admission_Deposit)
plt.title('Histogram of Admission_deposit')
# Out:
# Text(0.5, 1.0, 'Histogram of Admission_deposit')

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
raw_train_data['Stay'] = lb.fit_transform(raw_train_data['Stay'])
raw_train_data['Stay']
# Out:
# 0         0
# 1         4
# 2         3
# 3         4
# 4         4
#          ..
# 318433    1
# 318434    3
# 318435    1
# 318436    1
# 318437    0
# Name: Stay, Length: 318438, dtype: int64

# %%
#fig, axs = plt.subplots(ncols=2)
fig, ax = plt.subplots(figsize=(10,10))
sns.set_theme(style="whitegrid", color_codes=True)
col = raw_train_data.groupby("Stay").size()
pal = sns.color_palette("Greens_d", len(col))
rank = col.argsort().argsort() 
sns.barplot(data=raw_train_data, x='Department', y='Stay', color = 'lightseagreen', hue_order = 'Department', ax=ax).set(title='Bar plots between Stay and differnt departments') 
#sns.barplot(data=raw_train_data, x='Department', y='Stay', palette=np.array(pal[::-1])[rank],ax=ax) #color ='salmon', hue = 'department'
#sns.countplot(data=raw_train_data, x='Department')
#_ = plt.setp(s.get_xticklabels(), rotation=90)
# Out:
# [Text(0.5, 1.0, 'Bar plots between Stay and differnt departments')]

# %%
for i in cat_features:
    fig, ax = plt.subplots(figsize=(10,10))
    sns.set_theme(style="whitegrid")
    sns.barplot(data=raw_train_data, x=i, y='Stay',color = 'indianred',ax=ax).set(title='Stay v/s '+i )

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.set_theme(style="whitegrid")
sns.barplot(data=raw_train_data, x='Bed Grade',color='goldenrod', y='Stay',ax=ax).set(title='Stay v/s bed Grade')
# Out:
# [Text(0.5, 1.0, 'Stay v/s bed Grade')]

# %%
raw_train_data['Visitors with Patient'].value_counts()
# Out:
# 2     138417
# 4      79225
# 3      59180
# 6      18860
# 5       9219
# 8       4872
# 7       2504
# 9       1358
# 1       1207
# 10      1183
# 12       968
# 11       327
# 16       286
# 14       207
# 15       194
# 13       106
# 24        78
# 20        62
# 18        61
# 0         22
# 17        20
# 22        19
# 19        12
# 25        12
# 21        11
# 23        10
# 32         9
# 30         9
# Name: Visitors with Patient, dtype: int64

# %%
stay_bar = raw_train_data['Stay'].value_counts().to_frame()

# %%
stay_bar.reset_index(inplace=True)

# %%
stay_bar.rename({'index': 'Stay', 'Stay':'Count'}, inplace=True, axis=1)

# %%
sns.barplot(data=stay_bar, x = 'Stay', y='Count', color='pink').set(title='Count v/s Stay')
'''col = raw_train_data.groupby('Stay').size()
pal = sns.color_palette("Greens_d", len(col))
rank = col.argsort().argsort() '''
#sns.barplot(data=raw_train_data, x = 'Stay', y='Count', palette=np.array(pal[::-1])[rank],ax=ax)
# Out:
# 'col = raw_train_data.groupby(\'Stay\').size()\npal = sns.color_palette("Greens_d", len(col))\nrank = col.argsort().argsort() '

# %% [markdown]
# ### 4.3 Determine the Data Quality Issues - Missing Values and Outliers

# %%
# get the missing values
raw_train_data.isna().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
#There are missing values in Bed Grade and City_Code_Patient which are 0.035% and 1.44%. % of missing values is very less so we can perform imputation without any hesistation.

# %% [markdown]
# | Feature | Data Quality Issues | Potential Handling Strategies |
# | ----------- | ----------- | ----------- |
# | Bed Grade | 113 Missing Values | 0.035% missing values. We are not dropping any data. We will perform imputation with Median. |
# | City_Code_Patient | 4532 Missing Values | 1.44% missing values. We are not dropping any data. We will perform imputation with Median|

# %% [markdown]
# ### 4.4 Handling Data Quality Issues

# %%
# handling missing values on Bed Grade
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,  
                        strategy ='median')
si.fit(raw_train_data[['Bed Grade']])
raw_train_data['Bed Grade'] = si.transform(raw_train_data[['Bed Grade']])
raw_train_data.isna().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                               0
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# Stay                                    0
# dtype: int64

# %%
# handling missing values on City_Code_Patient
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan,  
                        strategy ='median')
si.fit(raw_train_data[['City_Code_Patient']])
raw_train_data['City_Code_Patient'] = si.transform(raw_train_data[['City_Code_Patient']])
raw_train_data.isna().sum()
# Out:
# case_id                              0
# Hospital_code                        0
# Hospital_type_code                   0
# City_Code_Hospital                   0
# Hospital_region_code                 0
# Available Extra Rooms in Hospital    0
# Department                           0
# Ward_Type                            0
# Ward_Facility_Code                   0
# Bed Grade                            0
# patientid                            0
# City_Code_Patient                    0
# Type of Admission                    0
# Severity of Illness                  0
# Visitors with Patient                0
# Age                                  0
# Admission_Deposit                    0
# Stay                                 0
# dtype: int64

# %% [markdown]
# ## 4.4 Data Preperation
#
# > We will use encodings on following descriptive features:
#      Age,
#      Severity of Illness,
#      City_Code_Patient,
#      Hospital_type_code,
#      Hospital_region_code,
#      Department,
#      Ward_Type,
#      Ward_Facility_Code,
#      Type of Admission.

# %%
# encoding on age
lb = LabelEncoder()
raw_train_data['Age'] = lb.fit_transform(raw_train_data['Age'])
raw_train_data['Age']
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 318433    4
# 318434    8
# 318435    7
# 318436    1
# 318437    1
# Name: Age, Length: 318438, dtype: int64

# %% [markdown]
# #### Encoding Severity of Illness:
# 0: Extreme
# 1: Moderate
# 2: Minor

# %%
# encoding on severity of illness
lb = LabelEncoder()
raw_train_data['Severity of Illness'] = lb.fit_transform(raw_train_data['Severity of Illness'])
raw_train_data['Severity of Illness']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 318433    2
# 318434    2
# 318435    1
# 318436    1
# 318437    1
# Name: Severity of Illness, Length: 318438, dtype: int64

# %%
sns.scatterplot(data=raw_train_data, y='Admission_Deposit', x='Stay').set(title='Admission_deposit v/s Stay')
# Out:
# [Text(0.5, 1.0, 'Admission_deposit v/s Stay')]

# %% [markdown]
# <!-- #### Stay encoding:
#
# 0-10: 0,
#
#
# 11-20: 1,
#
#
# 21-30: 2,
#
#
# 31-40: 3,
#
#
# 41-50: 4,
#
#
# 51-60: 5,
#
#
# 61-70: 6,
# .
# .
# .
# . -->

# %%
# we will apply encoding to convert remaining categorical features into numerics.
lb = LabelEncoder()
raw_train_data['Hospital_type_code'] = lb.fit_transform(raw_train_data['Hospital_type_code'])
raw_train_data['Hospital_region_code'] = lb.fit_transform(raw_train_data['Hospital_region_code'])
raw_train_data['Department'] = lb.fit_transform(raw_train_data['Department'])
raw_train_data['Ward_Type'] = lb.fit_transform(raw_train_data['Ward_Type'])
raw_train_data['Ward_Facility_Code'] = lb.fit_transform(raw_train_data['Ward_Facility_Code'])
raw_train_data['Type of Admission'] = lb.fit_transform(raw_train_data['Type of Admission'])

# %%
# finally printing data this is our final processed data
raw_train_data
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0             1              8                   2                   3
# 1             2              2                   2                   5
# 2             3             10                   4                   1
# 3             4             26                   1                   2
# 4             5             26                   1                   2
# ...         ...            ...                 ...                 ...
# 318433   318434              6                   0                   6
# 318434   318435             24                   0                   1
# 318435   318436              7                   0                   4
# 318436   318437             11                   1                   2
# 318437   318438             19                   0                   7
#
#         Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                          2                                  3           3
# 1                          2                                  2           3
# 2                          0                                  2           1
# 3                          1                                  2           3
# 4                          1                                  2           3
# ...                      ...                                ...         ...
# 318433                     0                                  3           3
# 318434                     0                                  2           1
# 318435                     0                                  3           2
# 318436                     1                                  3           1
# 318437                     1                                  5           2
#
#         Ward_Type  Ward_Facility_Code  Bed Grade  patientid  \
# 0               2                   5        2.0      31397
# 1               3                   5        2.0      31397
# 2               3                   4        2.0      31397
# 3               2                   3        2.0      31397
# 4               3                   3        2.0      31397
# ...           ...                 ...        ...        ...
# 318433          1                   5        4.0      86499
# 318434          1                   4        4.0        325
# 318435          2                   5        4.0     125235
# 318436          1                   3        3.0      91081
# 318437          1                   2        2.0      21641
#
#         City_Code_Patient  Type of Admission  Severity of Illness  \
# 0                     7.0                  0                    0
# 1                     7.0                  1                    0
# 2                     7.0                  1                    0
# 3                     7.0                  1                    0
# 4                     7.0                  1                    0
# ...                   ...                ...                  ...
# 318433               23.0                  0                    2
# 318434                8.0                  2                    2
# 318435               10.0                  0                    1
# 318436                8.0                  1                    1
# 318437                8.0                  0                    1
#
#         Visitors with Patient  Age  Admission_Deposit  Stay
# 0                           2    5             4911.0     0
# 1                           2    5             5954.0     4
# 2                           2    5             4745.0     3
# 3                           2    5             7272.0     4
# 4                           2    5             5558.0     4
# ...                       ...  ...                ...   ...
# 318433                      3    4             4144.0     1
# 318434                      4    8             6699.0     3
# 318435                      3    7             4235.0     1
# 318436                      5    1             3761.0     1
# 318437                      2    1             4752.0     0
#
# [318438 rows x 18 columns]

# %% [markdown]
# # 5. Analysis

# %% [markdown]
# ### 5.1 Correlation Heatmap

# %%
# sns.heatmap(raw_train_data.corr())
# # # fig, ax = plt.subplots(figsize=(18,18))

corr_mat = raw_train_data.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr_mat, annot=False, linewidths=.5, ax=ax, cmap="Greens").set(title='Correlation matrix')
# Out:
# [Text(0.5, 1.0, 'Correlation matrix')]

# %% [markdown]
# ### 5.2 Stay vs Hospital Code

# %%
sns.barplot(data=raw_train_data, x='Hospital_code', y='Stay', color='skyblue').set(title= "Stay v/s Hospital_code")
# Out:
# [Text(0.5, 1.0, 'Stay v/s Hospital_code')]

# %% [markdown]
# ### 5.3 Admission Deposit vs Stay

# %%
# sns.

# admission depo is only one continous feature in dataset. Let's plot the barplot.

sns.barplot(data=raw_train_data, x='Stay', y='Admission_Deposit', color='olivedrab').set(title= "Admission_deposit v/s Stay")
# Out:
# [Text(0.5, 1.0, 'Admission_deposit v/s Stay')]

# %% [markdown]
# ### 5.4 Unique Hospital Codes

# %%
# getting unique hospital code from dataset
raw_train_data['Hospital_code'].unique()
# Out:
# array([ 8,  2, 10, 26, 23, 32,  1, 22, 16,  9,  6, 29, 12,  3, 21, 28, 27,
#        19,  5, 14, 13, 31, 24, 17, 25, 15, 11, 30, 18,  4,  7, 20])

# %% [markdown]
# ### 5.5 Correlation Matrix

# %%
raw_train_data.corr()
# Out:
#                                     case_id  Hospital_code  \
# case_id                            1.000000      -0.043023
# Hospital_code                     -0.043023       1.000000
# Hospital_type_code                 0.001877       0.039449
# City_Code_Hospital                -0.011352       0.128294
# Hospital_region_code               0.006262      -0.135920
# Available Extra Rooms in Hospital  0.042580      -0.059638
# Department                        -0.002175       0.000777
# Ward_Type                         -0.029183       0.161108
# Ward_Facility_Code                -0.011546      -0.132347
# Bed Grade                          0.013691      -0.013948
# patientid                         -0.004150       0.002291
# City_Code_Patient                  0.065207      -0.015477
# Type of Admission                  0.076789      -0.014268
# Severity of Illness                0.013935      -0.007585
# Visitors with Patient              0.001309      -0.028500
# Age                               -0.114694       0.016322
# Admission_Deposit                 -0.045972       0.045446
# Stay                              -0.053882       0.042846
#
#                                    Hospital_type_code  City_Code_Hospital  \
# case_id                                      0.001877           -0.011352
# Hospital_code                                0.039449            0.128294
# Hospital_type_code                           1.000000           -0.000839
# City_Code_Hospital                          -0.000839            1.000000
# Hospital_region_code                         0.268962            0.008311
# Available Extra Rooms in Hospital           -0.103044           -0.045771
# Department                                   0.001768            0.029308
# Ward_Type                                    0.246347            0.122285
# Ward_Facility_Code                          -0.265768           -0.100474
# Bed Grade                                    0.018642           -0.049248
# patientid                                   -0.003010            0.000750
# City_Code_Patient                            0.055272           -0.024161
# Type of Admission                            0.080073           -0.015547
# Severity of Illness                         -0.004625           -0.000018
# Visitors with Patient                       -0.045213            0.018184
# Age                                          0.006030            0.020507
# Admission_Deposit                            0.025341           -0.034455
# Stay                                         0.058592            0.006381
#
#                                    Hospital_region_code  \
# case_id                                        0.006262
# Hospital_code                                 -0.135920
# Hospital_type_code                             0.268962
# City_Code_Hospital                             0.008311
# Hospital_region_code                           1.000000
# Available Extra Rooms in Hospital             -0.006906
# Department                                     0.041499
# Ward_Type                                      0.077769
# Ward_Facility_Code                            -0.507350
# Bed Grade                                     -0.042680
# patientid                                     -0.002083
# City_Code_Patient                              0.150714
# Type of Admission                              0.005602
# Severity of Illness                           -0.006067
# Visitors with Patient                         -0.019485
# Age                                           -0.017083
# Admission_Deposit                              0.075092
# Stay                                           0.011905
#
#                                    Available Extra Rooms in Hospital  \
# case_id                                                     0.042580
# Hospital_code                                              -0.059638
# Hospital_type_code                                         -0.103044
# City_Code_Hospital                                         -0.045771
# Hospital_region_code                                       -0.006906
# Available Extra Rooms in Hospital                           1.000000
# Department                                                  0.047726
# Ward_Type                                                  -0.433849
# Ward_Facility_Code                                          0.050453
# Bed Grade                                                  -0.115804
# patientid                                                   0.000921
# City_Code_Patient                                          -0.009462
# Type of Admission                                          -0.016498
# Severity of Illness                                         0.015053
# Visitors with Patient                                       0.096714
# Age                                                        -0.133491
# Admission_Deposit                                          -0.143739
# Stay                                                       -0.121120
#
#                                    Department  Ward_Type  Ward_Facility_Code  \
# case_id                             -0.002175  -0.029183           -0.011546
# Hospital_code                        0.000777   0.161108           -0.132347
# Hospital_type_code                   0.001768   0.246347           -0.265768
# City_Code_Hospital                   0.029308   0.122285           -0.100474
# Hospital_region_code                 0.041499   0.077769           -0.507350
# Available Extra Rooms in Hospital    0.047726  -0.433849            0.050453
# Department                           1.000000  -0.005972           -0.040371
# Ward_Type                           -0.005972   1.000000           -0.155031
# Ward_Facility_Code                  -0.040371  -0.155031            1.000000
# Bed Grade                           -0.096745  -0.013484            0.075984
# patientid                            0.002217   0.000615            0.001923
# City_Code_Patient                    0.019500   0.015692           -0.139691
# Type of Admission                   -0.080768   0.012701            0.043242
# Severity of Illness                 -0.008075   0.001503            0.014844
# Visitors with Patient                0.026054  -0.096451            0.022088
# Age                                  0.035518   0.024332           -0.000417
# Admission_Deposit                   -0.080754   0.050825           -0.023057
# Stay                                 0.033287   0.185191           -0.004552
#
#                                    Bed Grade  patientid  City_Code_Patient  \
# case_id                             0.013691  -0.004150           0.065207
# Hospital_code                      -0.013948   0.002291          -0.015477
# Hospital_type_code                  0.018642  -0.003010           0.055272
# City_Code_Hospital                 -0.049248   0.000750          -0.024161
# Hospital_region_code               -0.042680  -0.002083           0.150714
# Available Extra Rooms in Hospital  -0.115804   0.000921          -0.009462
# Department                         -0.096745   0.002217           0.019500
# Ward_Type                          -0.013484   0.000615           0.015692
# Ward_Facility_Code                  0.075984   0.001923          -0.139691
# Bed Grade                           1.000000   0.001638          -0.007581
# patientid                           0.001638   1.000000           0.002009
# City_Code_Patient                  -0.007581   0.002009           1.000000
# Type of Admission                   0.126075   0.002498          -0.026921
# Severity of Illness                 0.049951   0.004444          -0.007774
# Visitors with Patient               0.088920   0.006889          -0.011677
# Age                                 0.001717  -0.001505          -0.016282
# Admission_Deposit                   0.073779  -0.000877           0.025485
# Stay                                0.025761   0.001125          -0.009447
#
#                                    Type of Admission  Severity of Illness  \
# case_id                                     0.076789             0.013935
# Hospital_code                              -0.014268            -0.007585
# Hospital_type_code                          0.080073            -0.004625
# City_Code_Hospital                         -0.015547            -0.000018
# Hospital_region_code                        0.005602            -0.006067
# Available Extra Rooms in Hospital          -0.016498             0.015053
# Department                                 -0.080768            -0.008075
# Ward_Type                                   0.012701             0.001503
# Ward_Facility_Code                          0.043242             0.014844
# Bed Grade                                   0.126075             0.049951
# patientid                                   0.002498             0.004444
# City_Code_Patient                          -0.026921            -0.007774
# Type of Admission                           1.000000             0.011542
# Severity of Illness                         0.011542             1.000000
# Visitors with Patient                      -0.097966            -0.020670
# Age                                        -0.063396            -0.036090
# Admission_Deposit                           0.043352             0.023993
# Stay                                        0.023617            -0.031188
#
#                                    Visitors with Patient       Age  \
# case_id                                         0.001309 -0.114694
# Hospital_code                                  -0.028500  0.016322
# Hospital_type_code                             -0.045213  0.006030
# City_Code_Hospital                              0.018184  0.020507
# Hospital_region_code                           -0.019485 -0.017083
# Available Extra Rooms in Hospital               0.096714 -0.133491
# Department                                      0.026054  0.035518
# Ward_Type                                      -0.096451  0.024332
# Ward_Facility_Code                              0.022088 -0.000417
# Bed Grade                                       0.088920  0.001717
# patientid                                       0.006889 -0.001505
# City_Code_Patient                              -0.011677 -0.016282
# Type of Admission                              -0.097966 -0.063396
# Severity of Illness                            -0.020670 -0.036090
# Visitors with Patient                           1.000000  0.073795
# Age                                             0.073795  1.000000
# Admission_Deposit                              -0.150358  0.025182
# Stay                                            0.537537  0.094163
#
#                                    Admission_Deposit      Stay
# case_id                                    -0.045972 -0.053882
# Hospital_code                               0.045446  0.042846
# Hospital_type_code                          0.025341  0.058592
# City_Code_Hospital                         -0.034455  0.006381
# Hospital_region_code                        0.075092  0.011905
# Available Extra Rooms in Hospital          -0.143739 -0.121120
# Department                                 -0.080754  0.033287
# Ward_Type                                   0.050825  0.185191
# Ward_Facility_Code                         -0.023057 -0.004552
# Bed Grade                                   0.073779  0.025761
# patientid                                  -0.000877  0.001125
# City_Code_Patient                           0.025485 -0.009447
# Type of Admission                           0.043352  0.023617
# Severity of Illness                         0.023993 -0.031188
# Visitors with Patient                      -0.150358  0.537537
# Age                                         0.025182  0.094163
# Admission_Deposit                           1.000000 -0.052077
# Stay                                       -0.052077  1.000000

# %% [markdown]
# ### 5.6 Important Questions need to be answered in Analysis

# %% [markdown]
# 1. Cases per Hospital
# 2. How many hospitals fall in each cities
# 3. Do the patient prefer same hospital everytime?
# 4. Which is the most visited department?
# 5. How often did the patient visit hospital?
# 6. Do older people stay longer?
# 7. Is initial admission deposit related to their stay?
# 8. Impact of severity of illness on Stay

# %% [markdown]
# ### 5.6.1 Cases per Hospital?

# %%
hosp_visits=raw_train_data['Hospital_code'].value_counts().to_frame().reset_index().rename(columns={'index':'hospital','Hospital_code':'total'})

# %%
hosp_visits
# Out:
#     hospital  total
# 0         26  33076
# 1         23  26566
# 2         19  21219
# 3          6  20425
# 4         11  17328
# 5         14  17328
# 6         28  17137
# 7         27  14244
# 8          9  11510
# 9         29  11311
# 10        12  11297
# 11        32  10703
# 12        25   9834
# 13        10   9435
# 14        15   9257
# 15        21   8150
# 16        24   7992
# 17         3   7116
# 18        17   5501
# 19         5   5261
# 20         1   5249
# 21        13   5236
# 22         2   5102
# 23        30   5002
# 24        22   4277
# 25        31   3967
# 26        16   3671
# 27         8   3663
# 28        18   3630
# 29        20   1405
# 30         7   1306
# 31         4   1240

# %%
sns.lineplot(data=hosp_visits, x=hosp_visits['hospital'], y=hosp_visits['total']).set(title= "Total cases v/s Hospital")
# Out:
# [Text(0.5, 1.0, 'Total cases v/s Hospital')]

# %%
hosp_visits['total'].sum() / 32
# Out:
# 9951.1875

# %% [markdown]
# #### Observations :
#     - 32 hospitals have dealt 318438 admission cases for 92017 patients
#     - Global average ratio of cases to hospital : 9951 cases per hospital

# %% [markdown]
# ### 5.6.2 Which city has the highest number of hospitals and which city has the lowest number of hospitals?

# %%
hosp_cities = raw_train_data.groupby(['City_Code_Hospital', 'Hospital_code']).size().to_frame()

# %%
hosp_cities.rename({0: 'total'}, inplace=True, axis=1)

# %%
hosp_cities.drop('total', axis=1, inplace=True)

# %%
hosp_cities = hosp_cities.reset_index()

# %%
hosp_cities['City_Code_Hospital'].value_counts()
# Out:
# 1     6
# 3     6
# 5     4
# 2     3
# 4     3
# 9     3
# 6     2
# 7     2
# 10    1
# 11    1
# 13    1
# Name: City_Code_Hospital, dtype: int64

# %%
sns.countplot(x='City_Code_Hospital', data=hosp_cities, color='orange').set(title= "Count v/s city_Hospital_code")
# Out:
# [Text(0.5, 1.0, 'Count v/s city_Hospital_code')]

# %% [markdown]
# #### Observations:
#     As you can see city 1, city 3 has the highest number of hospitals.
#     City 10, 11, 13 has the lowest number of hospitals.

# %% [markdown]
# ### 5.6.3 Do the patients prefer same hospital everytime?

# %%
unique_ids = raw_train_data['patientid'].unique()
unique_ids
# Out:
# array([ 31397,  63418,   8088, ..., 125235,  91081,  21641])

# %%
patient_hosp = raw_train_data.groupby(['patientid', 'Hospital_code']).size().to_frame()

# %%
patient_hosp.drop(0, axis=1, inplace=True)

# %%
count_patients_visits = patient_hosp.groupby('patientid').size().sort_values(ascending=False).to_frame()

# %%
count_patients_visits.rename({0: 'hospital_count'}, inplace=True, axis=1)

# %%
count_patients_visits.reset_index(inplace=True)

# %%
sns.displot(count_patients_visits['hospital_count']).set(title= " total count of patients v/s Number of hosipitals ")

# %%
count_patients_visits[count_patients_visits['hospital_count'] == 1].count()
# Out:
# patientid         22553
# hospital_count    22553
# dtype: int64

# %%
count_patients_visits.count()
# Out:
# patientid         92017
# hospital_count    92017
# dtype: int64

# %%
22553/92017
# Out:
# 0.2450960148668181

# %%
count_patients_visits[count_patients_visits['hospital_count'] >= 3].count()
# Out:
# patientid         48093
# hospital_count    48093
# dtype: int64

# %%
48093/92017
# Out:
# 0.5226534227371029

# %%
count_patients_visits[count_patients_visits['hospital_count'] > 3].count()
# Out:
# patientid         30451
# hospital_count    30451
# dtype: int64

# %%
30451 / 92017
# Out:
# 0.33092798069921864

# %% [markdown]
# #### Observations:
# As you can see, most patients visits only one hospital. There are more than 20,000 patients who visited a single hospital only.

# %% [markdown]
# ### 5.6.4 Which is the most visited department?

# %%
raw_train_data
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0             1              8                   2                   3
# 1             2              2                   2                   5
# 2             3             10                   4                   1
# 3             4             26                   1                   2
# 4             5             26                   1                   2
# ...         ...            ...                 ...                 ...
# 318433   318434              6                   0                   6
# 318434   318435             24                   0                   1
# 318435   318436              7                   0                   4
# 318436   318437             11                   1                   2
# 318437   318438             19                   0                   7
#
#         Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                          2                                  3           3
# 1                          2                                  2           3
# 2                          0                                  2           1
# 3                          1                                  2           3
# 4                          1                                  2           3
# ...                      ...                                ...         ...
# 318433                     0                                  3           3
# 318434                     0                                  2           1
# 318435                     0                                  3           2
# 318436                     1                                  3           1
# 318437                     1                                  5           2
#
#         Ward_Type  Ward_Facility_Code  Bed Grade  patientid  \
# 0               2                   5        2.0      31397
# 1               3                   5        2.0      31397
# 2               3                   4        2.0      31397
# 3               2                   3        2.0      31397
# 4               3                   3        2.0      31397
# ...           ...                 ...        ...        ...
# 318433          1                   5        4.0      86499
# 318434          1                   4        4.0        325
# 318435          2                   5        4.0     125235
# 318436          1                   3        3.0      91081
# 318437          1                   2        2.0      21641
#
#         City_Code_Patient  Type of Admission  Severity of Illness  \
# 0                     7.0                  0                    0
# 1                     7.0                  1                    0
# 2                     7.0                  1                    0
# 3                     7.0                  1                    0
# 4                     7.0                  1                    0
# ...                   ...                ...                  ...
# 318433               23.0                  0                    2
# 318434                8.0                  2                    2
# 318435               10.0                  0                    1
# 318436                8.0                  1                    1
# 318437                8.0                  0                    1
#
#         Visitors with Patient  Age  Admission_Deposit  Stay
# 0                           2    5             4911.0     0
# 1                           2    5             5954.0     4
# 2                           2    5             4745.0     3
# 3                           2    5             7272.0     4
# 4                           2    5             5558.0     4
# ...                       ...  ...                ...   ...
# 318433                      3    4             4144.0     1
# 318434                      4    8             6699.0     3
# 318435                      3    7             4235.0     1
# 318436                      5    1             3761.0     1
# 318437                      2    1             4752.0     0
#
# [318438 rows x 18 columns]

# %%
raw_train_data.groupby(['patientid', 'Department']).size()
# Out:
# patientid  Department
# 1          2             4
# 2          1             1
#            2             1
# 4          2             2
# 6          2             1
#                         ..
# 131621     2             3
# 131622     0             1
#            2             3
# 131623     2             2
# 131624     2             3
# Length: 123861, dtype: int64

# %%
dept_visits = raw_train_data.groupby(['Department']).size().to_frame().reset_index()

# %%
dept_visits.rename({0:'total_visits'}, inplace=True, axis=1)

# %%
dept_visits
# Out:
#    Department  total_visits
# 0           0          9586
# 1           1         29649
# 2           2        249486
# 3           3         28516
# 4           4          1201

# %%
sns.barplot(data=dept_visits, y = 'total_visits', x='Department', palette='light:b').set(title= "total_visits v/s Department")
# Out:
# [Text(0.5, 1.0, 'total_visits v/s Department')]

# %% [markdown]
# #### Obseravtions:
#     Gynecology department has most number of visitors

# %% [markdown]
# ### 5.6.5 Frequency of visits of patients?

# %%
num_visits_patients= raw_train_data['patientid'].value_counts().to_frame()

# %%
num_visits_patients.reset_index(inplace=True)

# %%
num_visits_patients.rename({'index':'patientid', 'patientid': 'total_visits'}, inplace=True, axis=1)

# %%
num_visits_patients.groupby('total_visits').size()
# Out:
# total_visits
# 1     20349
# 2     18535
# 3     15656
# 4     12336
# 5      9266
# 6      6292
# 7      4054
# 8      2342
# 9      1396
# 10      761
# 11      400
# 12      273
# 13      111
# 14       74
# 15       56
# 16       26
# 17       24
# 18       17
# 19        7
# 20        8
# 21        5
# 22        5
# 23        4
# 24        2
# 25        2
# 26        3
# 27        2
# 28        1
# 29        1
# 30        2
# 31        1
# 32        1
# 34        1
# 36        1
# 39        1
# 43        1
# 50        1
# dtype: int64

# %%
sns.scatterplot(data = num_visits_patients, y = "total_visits", x = "patientid").set(title= "total_visits v/s patient_id")
# Out:
# [Text(0.5, 1.0, 'total_visits v/s patient_id')]

# %%
20349 / 92017
# Out:
# 0.22114391905843486

# %% [markdown]
# #### Observations:
#         As you can see 22% of total patients visited hospital for once only.
#         50% of patients have tried more than 3 hospitals

# %% [markdown]
# ### 5.6.6 Do older people stay longer ?

# %%
raw_train_data
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0             1              8                   2                   3
# 1             2              2                   2                   5
# 2             3             10                   4                   1
# 3             4             26                   1                   2
# 4             5             26                   1                   2
# ...         ...            ...                 ...                 ...
# 318433   318434              6                   0                   6
# 318434   318435             24                   0                   1
# 318435   318436              7                   0                   4
# 318436   318437             11                   1                   2
# 318437   318438             19                   0                   7
#
#         Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                          2                                  3           3
# 1                          2                                  2           3
# 2                          0                                  2           1
# 3                          1                                  2           3
# 4                          1                                  2           3
# ...                      ...                                ...         ...
# 318433                     0                                  3           3
# 318434                     0                                  2           1
# 318435                     0                                  3           2
# 318436                     1                                  3           1
# 318437                     1                                  5           2
#
#         Ward_Type  Ward_Facility_Code  Bed Grade  patientid  \
# 0               2                   5        2.0      31397
# 1               3                   5        2.0      31397
# 2               3                   4        2.0      31397
# 3               2                   3        2.0      31397
# 4               3                   3        2.0      31397
# ...           ...                 ...        ...        ...
# 318433          1                   5        4.0      86499
# 318434          1                   4        4.0        325
# 318435          2                   5        4.0     125235
# 318436          1                   3        3.0      91081
# 318437          1                   2        2.0      21641
#
#         City_Code_Patient  Type of Admission  Severity of Illness  \
# 0                     7.0                  0                    0
# 1                     7.0                  1                    0
# 2                     7.0                  1                    0
# 3                     7.0                  1                    0
# 4                     7.0                  1                    0
# ...                   ...                ...                  ...
# 318433               23.0                  0                    2
# 318434                8.0                  2                    2
# 318435               10.0                  0                    1
# 318436                8.0                  1                    1
# 318437                8.0                  0                    1
#
#         Visitors with Patient  Age  Admission_Deposit  Stay
# 0                           2    5             4911.0     0
# 1                           2    5             5954.0     4
# 2                           2    5             4745.0     3
# 3                           2    5             7272.0     4
# 4                           2    5             5558.0     4
# ...                       ...  ...                ...   ...
# 318433                      3    4             4144.0     1
# 318434                      4    8             6699.0     3
# 318435                      3    7             4235.0     1
# 318436                      5    1             3761.0     1
# 318437                      2    1             4752.0     0
#
# [318438 rows x 18 columns]

# %%
age_stay = raw_train_data.groupby(['Age', 'Stay']).size().to_frame()

# %%
sns.boxplot(data=raw_train_data, x = 'Age', y = 'Stay', color='thistle').set(title= "Stay v/s Age")
# Out:
# [Text(0.5, 1.0, 'Stay v/s Age')]

# %%
age_count = raw_train_data.groupby('Age').size().to_frame().reset_index()

# %%
age_count.rename({0:'total_count'}, inplace=True, axis=1)

# %%
sns.barplot(data=age_count, x = 'Age', y = 'total_count', color='lightgreen').set(title= "Total_count v/s Age")
# Out:
# [Text(0.5, 1.0, 'Total_count v/s Age')]

# %%
# no of patients age >= 8
raw_train_data[raw_train_data['Age'] >= 8].count()
# Out:
# case_id                              9192
# Hospital_code                        9192
# Hospital_type_code                   9192
# City_Code_Hospital                   9192
# Hospital_region_code                 9192
# Available Extra Rooms in Hospital    9192
# Department                           9192
# Ward_Type                            9192
# Ward_Facility_Code                   9192
# Bed Grade                            9192
# patientid                            9192
# City_Code_Patient                    9192
# Type of Admission                    9192
# Severity of Illness                  9192
# Visitors with Patient                9192
# Age                                  9192
# Admission_Deposit                    9192
# Stay                                 9192
# dtype: int64

# %% [markdown]
# #### Observations:
# As you can see age affects length of stay as older people tend to stay longer in hospitals.

# %% [markdown]
# ### 5.6.7 Is initial admission deposit related to their stay?

# %%
sns.boxplot(data=raw_train_data, x = 'Stay', y='Admission_Deposit', color='salmon' ).set(title= "Admission_deposit v/s Stay") #palette="Set3"
# Out:
# [Text(0.5, 1.0, 'Admission_deposit v/s Stay')]

# %%
sns.barplot(data=raw_train_data, x = 'Stay', y='Admission_Deposit', color='darkmagenta' ).set(title= "Admission_deposit v/s Stay")#palette="Set3"
# Out:
# [Text(0.5, 1.0, 'Admission_deposit v/s Stay')]

# %% [markdown]
# ### Observations:
# We can see there is no direct correlation between admission deposit and stay.

# %% [markdown]
# ### 5.6.8 Relationship between stay and severity of illness?

# %%
sns.barplot(data=raw_train_data, y = 'Stay', x = 'Severity of Illness', color='khaki').set(title= "Stay v/s Severity of Illness")
# Out:
# [Text(0.5, 1.0, 'Stay v/s Severity of Illness')]

# %% [markdown]
# #### Observations:
#     As you can see 0,i.e. extreme cases have significantly higher length of stay.

# %%
illness_data = raw_train_data.groupby('Severity of Illness').size().to_frame().reset_index()
illness_data.rename({0:'total_count'}, inplace=True, axis=1)

# %%
sns.barplot(data=illness_data, x = 'Severity of Illness', y='total_count', color='cadetblue').set(title= "Total_count v/s Severity of Illness")
# Out:
# [Text(0.5, 1.0, 'Total_count v/s Severity of Illness')]

# %% [markdown]
# #### Observations:
#     50%+ patients in given data are having minor severity.

# %%
count_severity = raw_train_data.groupby(['Severity of Illness', 'Age']).size().to_frame().reset_index()

# %%
count_severity.rename({0: 'total_count'}, inplace=True, axis=1)

# %%
count_severity
# Out:
#     Severity of Illness  Age  total_count
# 0                     0    0          658
# 1                     0    1         1358
# 2                     0    2         4237
# 3                     0    3        10219
# 4                     0    4        13393
# 5                     0    5        10467
# 6                     0    6         7215
# 7                     0    7         7038
# 8                     0    8         1842
# 9                     0    9          296
# 10                    1    0         2530
# 11                    1    1         8027
# 12                    1    2        15406
# 13                    1    3        16462
# 14                    1    4        12933
# 15                    1    5        10513
# 16                    1    6         8199
# 17                    1    7         9686
# 18                    1    8         1840
# 19                    1    9          276
# 20                    2    0         3066
# 21                    2    1         7383
# 22                    2    2        21200
# 23                    2    3        36958
# 24                    2    4        37423
# 25                    2    5        27534
# 26                    2    6        18273
# 27                    2    7        19068
# 28                    2    8         4208
# 29                    2    9          730

# %%
illness_data
# Out:
#    Severity of Illness  total_count
# 0                    0        56723
# 1                    1        85872
# 2                    2       175843
